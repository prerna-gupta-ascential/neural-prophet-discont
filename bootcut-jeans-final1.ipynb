# %%
import os    
os.environ['KMP_DUPLICATE_LIB_OK']='True'

# %%
import pandas as pd
from neuralprophet import NeuralProphet

# %%
from prophet import Prophet
import pandas as pd

# %%
from prophet import Prophet
import pandas as pd
s=pd.read_excel(r"C:\Users\prernagupta\Desktop\jeans-bf\bootcut.xlsx")
s
# Out:
#      trend_index          trend_name             trend   base  \
# 0            470  bootcut_jeans_uk_w  Bootcut Jeans Uk  Jeans
# 1            470  bootcut_jeans_uk_w  Bootcut Jeans Uk  Jeans
# 2            470  bootcut_jeans_uk_w  Bootcut Jeans Uk  Jeans
# 3            470  bootcut_jeans_uk_w  Bootcut Jeans Uk  Jeans
# 4            470  bootcut_jeans_uk_w  Bootcut Jeans Uk  Jeans
# ..           ...                 ...               ...    ...
# 360          470  bootcut_jeans_uk_w  Bootcut Jeans Uk  Jeans
# 361          470  bootcut_jeans_uk_w  Bootcut Jeans Uk  Jeans
# 362          470  bootcut_jeans_uk_w  Bootcut Jeans Uk  Jeans
# 363          470  bootcut_jeans_uk_w  Bootcut Jeans Uk  Jeans
# 364          470  bootcut_jeans_uk_w  Bootcut Jeans Uk  Jeans
#
#     model_created_at    season         ds         y       nsi  fsi_yhat_lower  \
# 0         2022-03-01  S/S 2017 2017-03-20  0.123154  0.131211        0.116408
# 1         2022-03-01  S/S 2017 2017-03-27  0.120903  0.123120        0.115918
# 2         2022-03-01  S/S 2017 2017-04-03  0.122260  0.116688        0.114757
# 3         2022-03-01  S/S 2017 2017-04-10  0.119924  0.111730        0.113931
# 4         2022-03-01  S/S 2017 2017-04-17  0.116062  0.108058        0.112205
# ..               ...       ...        ...       ...       ...             ...
# 360       2022-03-01  S/S 2024 2024-02-12       NaN       NaN        0.109251
# 361       2022-03-01  S/S 2024 2024-02-19       NaN       NaN        0.109714
# 362       2022-03-01  S/S 2024 2024-02-26       NaN       NaN        0.111063
# 363       2022-03-01  S/S 2024 2024-03-04       NaN       NaN        0.112711
# 364       2022-03-01  S/S 2024 2024-03-11       NaN       NaN        0.114135
#
#      fsi_yhat  fsi_yhat_upper                            fsi_pivot_points  \
# 0    0.127637        0.139071  ['2019-07-15', '2020-06-22', '2021-05-17']
# 1    0.127214        0.139281  ['2019-07-15', '2020-06-22', '2021-05-17']
# 2    0.126204        0.138178  ['2019-07-15', '2020-06-22', '2021-05-17']
# 3    0.124974        0.135769  ['2019-07-15', '2020-06-22', '2021-05-17']
# 4    0.123917        0.136174  ['2019-07-15', '2020-06-22', '2021-05-17']
# ..        ...             ...                                         ...
# 360  0.121250        0.133800  ['2019-07-15', '2020-06-22', '2021-05-17']
# 361  0.121882        0.134750  ['2019-07-15', '2020-06-22', '2021-05-17']
# 362  0.123108        0.136420  ['2019-07-15', '2020-06-22', '2021-05-17']
# 363  0.124454        0.137729  ['2019-07-15', '2020-06-22', '2021-05-17']
# 364  0.125433        0.139083  ['2019-07-15', '2020-06-22', '2021-05-17']
#
#      trending_index  newness_index  markdown_index  fashion_leaders_index  \
# 0          1.040471      -0.043780        1.084928               0.643579
# 1          1.015701      -0.025706        1.080867               0.642948
# 2          0.992146      -0.006570        1.076927               0.642290
# 3          0.969807       0.013627        1.073110               0.641604
# 4          0.948683       0.034886        1.069414               0.640891
# ..              ...            ...             ...                    ...
# 360             NaN            NaN             NaN                    NaN
# 361             NaN            NaN             NaN                    NaN
# 362             NaN            NaN             NaN                    NaN
# 363             NaN            NaN             NaN                    NaN
# 364             NaN            NaN             NaN                    NaN
#
#      oos_index  catwalk_impact
# 0     0.113342             0.0
# 1     0.108900             0.0
# 2     0.104278             0.0
# 3     0.099591             0.0
# 4     0.094953             0.0
# ..         ...             ...
# 360        NaN             NaN
# 361        NaN             NaN
# 362        NaN             NaN
# 363        NaN             NaN
# 364        NaN             NaN
#
# [365 rows x 19 columns]

# %%
s=s.iloc[:, [6, 7]]
s
s['ds']= pd.to_datetime(s['ds'])
s
# Out:
# WARNING - (py.warnings._showwarnmsg) - <ipython-input-90-60943957d9c4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s['ds']= pd.to_datetime(s['ds'])
#
# WARNING:py.warnings:<ipython-input-90-60943957d9c4>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   s['ds']= pd.to_datetime(s['ds'])
#             ds         y
# 0   2017-03-20  0.123154
# 1   2017-03-27  0.120903
# 2   2017-04-03  0.122260
# 3   2017-04-10  0.119924
# 4   2017-04-17  0.116062
# ..         ...       ...
# 360 2024-02-12       NaN
# 361 2024-02-19       NaN
# 362 2024-02-26       NaN
# 363 2024-03-04       NaN
# 364 2024-03-11       NaN
#
# [365 rows x 2 columns]

# %%
s=s.dropna()

# %%
m = NeuralProphet(growth="discontinuous",  # Determine trend types: 'linear', 'discontinuous', 'off'
        changepoints=None, # list of dates that may include change points (None -> automatic )
        n_changepoints=5,
        changepoints_range=1,
        trend_reg=0,
        trend_reg_threshold=False,
        yearly_seasonality=True,
        weekly_seasonality=False,
        daily_seasonality=False,
        seasonality_mode="additive",
        seasonality_reg=0,
        n_forecasts=1,
        n_lags=0,
        num_hidden_layers=0,
        d_hidden=None,     # Dimension of hidden layers of AR-Net
        ar_sparsity=None,  # Sparcity in the AR coefficients
        learning_rate=5,
        loss_func="Huber",
        normalize="auto",  # Type of normalization ('minmax', 'standardize', 'soft', 'off')
        impute_missing=True, epochs=5000)
metrics = m.fit(s, freq="7D")
future = m.make_future_dataframe(s, periods=75, n_historic_predictions=len(s))
forecast = m.predict(future)
# Out:
# INFO - (NP.config.set_auto_batch_epoch) - Auto-set batch_size to 16
# INFO:NP.config:Auto-set batch_size to 16
# Epoch[5000/5000]: 100%|█| 5000/5000 [05:11<00:00, 16.05it/s, SmoothL1Loss=0.00289, MAE=0.00467, RMSE=0.00664, RegLoss=0

# %%
metrics
# Out:
#       SmoothL1Loss       MAE      RMSE  RegLoss
# 0         0.428010  0.074289  0.087593      0.0
# 1         0.070646  0.028661  0.034111      0.0
# 2         0.055617  0.024946  0.030232      0.0
# 3         0.027371  0.017131  0.020938      0.0
# 4         0.019026  0.014362  0.017709      0.0
# ...            ...       ...       ...      ...
# 4995      0.002889  0.004674  0.006685      0.0
# 4996      0.002890  0.004675  0.006690      0.0
# 4997      0.002890  0.004675  0.006695      0.0
# 4998      0.002889  0.004675  0.006715      0.0
# 4999      0.002889  0.004675  0.006643      0.0
#
# [5000 rows x 4 columns]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(8, 6))
m.plot(forecast, xlabel="Date", ylabel="Temp", ax=ax)
ax.set_title("bootcut-jeans", fontsize=28, fontweight="bold")
# Out:
# Text(0.5, 1.0, 'bootcut-jeans')

# %%
fig_comp = m.plot_components(forecast)

# %%
def MAPE(Y_actual,Y_Predicted):
    mape = np.mean(np.abs((Y_actual - Y_Predicted)/Y_actual))*100
    return mape
import numpy as np

# %%
import numpy as np
forecast
# Out:
#             ds         y     yhat1  residual1     trend  season_yearly
# 0   2017-03-20  0.123154  0.114728  -0.008426  0.110230       0.004498
# 1   2017-03-27  0.120903  0.116075  -0.004828  0.111021       0.005054
# 2   2017-04-03  0.122260  0.116607  -0.005652  0.111812       0.004795
# 3   2017-04-10  0.119924  0.116526  -0.003397  0.112603       0.003923
# 4   2017-04-17  0.116062  0.116165   0.000103  0.113394       0.002771
# ..         ...       ...       ...        ...       ...            ...
# 331 2023-07-24       NaN  0.164315        NaN  0.169757      -0.005442
# 332 2023-07-31       NaN  0.164066        NaN  0.169934      -0.005868
# 333 2023-08-07       NaN  0.163591        NaN  0.170111      -0.006521
# 334 2023-08-14       NaN  0.163028        NaN  0.170289      -0.007261
# 335 2023-08-21       NaN  0.162702        NaN  0.170466      -0.007764
#
# [336 rows x 6 columns]

# %%
forecast1=forecast.dropna()
MAPE(forecast1['y'], forecast1['yhat1'])
# Out:
# 3.0533948555790764

# %%
#Here we do cross-validation to assess prediction performance on a horizon of 365 days, starting with 730 days of training data in the first cutoff and then making predictions every 180 days.
#On this 8 year time series, this corresponds to 11 total forecasts.

# %%
from prophet import Prophet
import pandas as pd
df=s
from prophet.plot import plot_yearly
m = Prophet().fit(df)
a = plot_yearly(m)



from prophet.plot import add_changepoints_to_plot
m = Prophet(changepoint_range=1.0)
# define the model
# fit the model
m.fit(df)
future = m.make_future_dataframe(periods=50, freq='W')

#prop only uses weekly seasonlity, and change points for first 80%
fcst = m.predict(future)
fig = m.plot(fcst)
a = add_changepoints_to_plot(fig.gca(), m, fcst)
# Out:
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.
# INFO:prophet:Disabling weekly seasonality. Run prophet with weekly_seasonality=True to override this.
# INFO:prophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
from prophet.diagnostics import cross_validation
df_cv = cross_validation(m, initial='730 days', period='180 days', horizon = '365 days')
# Out:
# INFO:prophet:Making 5 forecasts with cutoffs between 2019-03-25 00:00:00 and 2021-03-14 00:00:00
#   0%|          | 0/5 [00:00<?, ?it/s]

# %%
from prophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)
df_p.head()
# Out:
#   horizon       mse      rmse       mae      mape     mdape     smape  \
# 0 36 days  0.000359  0.018954  0.015501  0.082581  0.060614  0.079140
# 1 37 days  0.000407  0.020178  0.016769  0.089029  0.062263  0.085003
# 2 39 days  0.000405  0.020115  0.016679  0.088592  0.062263  0.084765
# 3 41 days  0.000438  0.020937  0.017609  0.093925  0.063984  0.089567
# 4 42 days  0.000439  0.020944  0.017623  0.093973  0.063984  0.089735
#
#    coverage
# 0  0.269231
# 1  0.230769
# 2  0.230769
# 3  0.192308
# 4  0.192308

# %%
from prophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv, metric='mape')

# %%
from prophet.diagnostics import cross_validation
df_cv = cross_validation(m, initial='1400 days', period='180 days', horizon = '365 days')
# Out:
# INFO:prophet:Making 1 forecasts with cutoffs between 2021-03-14 00:00:00 and 2021-03-14 00:00:00
#   0%|          | 0/1 [00:00<?, ?it/s]

# %%
from prophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)
df_p.head()
# Out:
#   horizon       mse      rmse       mae      mape     mdape     smape  \
# 0 29 days  0.000033  0.005743  0.005393  0.034499  0.035518  0.033836
# 1 36 days  0.000032  0.005677  0.005201  0.033333  0.035518  0.032685
# 2 43 days  0.000027  0.005162  0.004437  0.028506  0.025889  0.027969
# 3 50 days  0.000020  0.004483  0.003857  0.025001  0.025889  0.024588
# 4 57 days  0.000013  0.003572  0.003284  0.021544  0.025889  0.021271
#
#    coverage
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0

# %%
from prophet.plot import plot_cross_validation_metric
fig = plot_cross_validation_metric(df_cv, metric='mape')

# %%
from prophet.diagnostics import performance_metrics
df_p = performance_metrics(df_cv)
df_p.head()
# Out:
#   horizon       mse      rmse       mae      mape     mdape     smape  \
# 0 29 days  0.000033  0.005743  0.005393  0.034499  0.035518  0.033836
# 1 36 days  0.000032  0.005677  0.005201  0.033333  0.035518  0.032685
# 2 43 days  0.000027  0.005162  0.004437  0.028506  0.025889  0.027969
# 3 50 days  0.000020  0.004483  0.003857  0.025001  0.025889  0.024588
# 4 57 days  0.000013  0.003572  0.003284  0.021544  0.025889  0.021271
#
#    coverage
# 0       1.0
# 1       1.0
# 2       1.0
# 3       1.0
# 4       1.0

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
sqrt(mean_squared_error(forecast1['y'], forecast1['yhat1']) )
# Out:
# 0.007003238528607467
